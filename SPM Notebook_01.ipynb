# %%
import sys
# !{sys.executable} -m pip install pymongo azure-storage-blob boto3 fuzzywuzzy python-Levenshtein geopy google-cloud-storage google-auth
# Out:
# 'C:\Users\Sumaiya' is not recognized as an internal or external command,
# operable program or batch file.

# %%
 pip install pymongo azure-storage-blob boto3 fuzzywuzzy python-Levenshtein geopy requests google-cloud-storage google-auth
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -andas (c:\users\sumaiya gulshan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\sumaiya gulshan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\sumaiya gulshan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\sumaiya gulshan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\sumaiya gulshan\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\sumaiya gulshan\anaconda3\lib\site-packages)

# %%
import requests
import io
from google.cloud import storage
from google.oauth2 import service_account

# %%
 #For the PHYSICIANS datbase
#Download the CSV file from the link

# The path to your service account key file
key_path = "spm03-391922-00410eba94a3.json"
# Create a credentials object
creds = service_account.Credentials.from_service_account_file(key_path)
# Create a storage client with the credentials
storage_client = storage.Client(credentials=creds)

url = 'https://openpaymentsdata.cms.gov/api/1/datastore/query/23160558-6742-54ff-8b9f-cac7d514ff4e/0/download?&format=csv'
response = requests.get(url)
response.raise_for_status()

# Upload the file directly to Google Cloud Storage
project_id = 'spm03-391922'
bucket_name = 'bucket_spm_01'
blob_name = 'physicians.csv'
storage_client = storage.Client(credentials=creds, project=project_id)
bucket = storage_client.bucket(bucket_name)
blob = bucket.blob(blob_name)

blob.upload_from_string(response.content, content_type='text/csv')

# %%
# The path to your service account key file
key_path = "spm03-391922-00410eba94a3.json"
# Create a credentials object
creds = service_account.Credentials.from_service_account_file(key_path)
# Create a storage client with the credentials
storage_client = storage.Client(credentials=creds)
# The name of the bucket
bucket_name = "bucket_spm_01"
# Get the bucket
bucket = storage_client.get_bucket(bucket_name)
print("Bucket {} connected.".format(bucket.name))
# Out:
# Bucket bucket_spm_01 connected.

# %%
#For the OWNERSHIP datbase
#Download the CSV file from the link

# The path to your service account key file
key_path = "spm03-391922-00410eba94a3.json"
# Create a credentials object
creds = service_account.Credentials.from_service_account_file(key_path)
# Create a storage client with the credentials
storage_client = storage.Client(credentials=creds)

url = 'https://openpaymentsdata.cms.gov/api/1/datastore/query/b0c03b8d-06df-58f2-8ce2-4daeffee147e/0/download?&format=csv'
response = requests.get(url)
response.raise_for_status()

# Upload the file directly to Google Cloud Storage
project_id = 'spm03-391922'
bucket_name = 'bucket_spm_02'
blob_name = 'ownership.csv'
storage_client = storage.Client(credentials=creds, project=project_id)
bucket = storage_client.bucket(bucket_name)
blob = bucket.blob(blob_name)

blob.upload_from_string(response.content, content_type='text/csv')

# %%
# The path to your service account key file
key_path = "spm03-391922-00410eba94a3.json"
# Create a credentials object
creds = service_account.Credentials.from_service_account_file(key_path)
# Create a storage client with the credentials
storage_client = storage.Client(credentials=creds)
# The name of the bucket
bucket_name = "bucket_spm_02"
# Get the bucket
bucket = storage_client.get_bucket(bucket_name)
print("Bucket {} connected.".format(bucket.name))
# Out:
# Bucket bucket_spm_02 connected.

# %%
#For the GENERAL PAYMENT datbase
#Download the CSV file from the link

# The path to your service account key file
key_path = "spm03-391922-00410eba94a3.json"
# Create a credentials object
creds = service_account.Credentials.from_service_account_file(key_path)
# Create a storage client with the credentials
storage_client = storage.Client(credentials=creds)

url = 'https://openpaymentsdata.cms.gov/api/1/datastore/query/0380bbeb-aea1-58b6-b708-829f92a48202/0/download?&format=csv'
response = requests.get(url)
response.raise_for_status()

# Upload the file directly to Google Cloud Storage
project_id = 'spm03-391922'
bucket_name = 'bucket_spm_03'
blob_name = 'generalpayment.csv'
storage_client = storage.Client(credentials=creds, project=project_id)
bucket = storage_client.bucket(bucket_name)
blob = bucket.blob(blob_name)

blob.upload_from_string(response.content, content_type='text/csv')

# %%
#For the RESEARCH PAYMENT datbase
#Download the CSV file from the link

# The path to your service account key file
key_path = "spm03-391922-00410eba94a3.json"
# Create a credentials object
creds = service_account.Credentials.from_service_account_file(key_path)
# Create a storage client with the credentials
storage_client = storage.Client(credentials=creds)

url = 'https://openpaymentsdata.cms.gov/api/1/datastore/query/ce1d28dd-0094-5060-a036-580329439600/0/download?&format=csv'
response = requests.get(url)
response.raise_for_status()

# Upload the file directly to Google Cloud Storage
project_id = 'spm03-391922'
bucket_name = 'bucket_spm_04'
blob_name = 'researchpayment.csv'
storage_client = storage.Client(credentials=creds, project=project_id)
bucket = storage_client.bucket(bucket_name)
blob = bucket.blob(blob_name)

blob.upload_from_string(response.content, content_type='text/csv')

# %%
#For the PATIENT EXPERIENCE datbase
#Download the CSV file from the link

# The path to your service account key file
key_path = "spm03-391922-00410eba94a3.json"
# Create a credentials object
creds = service_account.Credentials.from_service_account_file(key_path)
# Create a storage client with the credentials
storage_client = storage.Client(credentials=creds)

url = 'https://data.cms.gov/provider-data/sites/default/files/resources/6083bb351293e72eda42881d6a93d803_1676693124/grp_public_reporting_cahps.csv'
response = requests.get(url)
response.raise_for_status()

# Upload the file directly to Google Cloud Storage
project_id = 'spm03-391922'
bucket_name = 'bucket_spm_05'
blob_name = 'patientexperience.csv'
storage_client = storage.Client(credentials=creds, project=project_id)
bucket = storage_client.bucket(bucket_name)
blob = bucket.blob(blob_name)

blob.upload_from_string(response.content, content_type='text/csv')

# %%
#data = request.get("https://openpaymentsdata.cms.gov/api/1/datastore/query/23160558-6742-54ff-8b9f-cac7d514ff4e/0/download?&format=csv")

# %%
import pandas as pd
df01 = pd.read_csv("physicians.csv")
df01.head()
# Out:
# C:\Users\Sumaiya Gulshan\AppData\Local\Temp\ipykernel_23380\1450819607.py:2: DtypeWarning: Columns (19,26,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   df01 = pd.read_csv("physicians.csv")
#   covered_recipient_profile_type  covered_recipient_profile_id  \
# 0    Covered Recipient Physician                         90372
# 1    Covered Recipient Physician                         90377
# 2    Covered Recipient Physician                         90406
# 3    Covered Recipient Physician                         90413
# 4    Covered Recipient Physician                         90420
#
#    associated_covered_recipient_profile_id_1  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    associated_covered_recipient_profile_id_2  covered_recipient_npi  \
# ...

# %%
# Read the CSV file into a DataFrame
df02 = pd.read_csv('ownership.csv')
df02.head()
# Out:
#   change_type  physician_profile_id  physician_npi physician_first_name  \
# 0         NEW               1076431   1.053344e+09                Faith
# 1         NEW                 83871   1.841285e+09                 Troy
# 2         NEW                 38369   1.851332e+09                 Anne
# 3         NEW                214233   1.720060e+09                David
# 4         NEW               1009793   1.700918e+09               Ingrid
#
#   physician_middle_name physician_last_name physician_name_suffix  \
# 0                   NaN              Brosch                   NaN
# 1                   NaN            Brothers                   NaN
# 2                   NaN               Brown                   NaN
# 3                   NaN               Brown                   NaN
# 4                   NaN               Brown                   NaN
#
#   recipient_primary_business_street_address_line1  \
# 0                   4745 OGLETOWN STANTON RD MAP1
# ...

# %%
# Read the CSV file into a DataFrame
df03 = pd.read_csv('generalpayments.csv')
df03.head()
# Out:
# C:\Users\Sumaiya Gulshan\AppData\Local\Temp\ipykernel_23380\4152983715.py:2: DtypeWarning: Columns (4,8,10,12,15,17,18,20,21,26,27,32,33,34,35,39,46,47,48,51,52,53,54,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88) have mixed types. Specify dtype option on import or set low_memory=False.
#   df03 = pd.read_csv('generalpayments.csv')
#   change_type       covered_recipient_type  teaching_hospital_ccn  \
# 0   UNCHANGED  Covered Recipient Physician                    NaN
# 1   UNCHANGED  Covered Recipient Physician                    NaN
# 2   UNCHANGED  Covered Recipient Physician                    NaN
# 3   UNCHANGED  Covered Recipient Physician                    NaN
# 4   UNCHANGED  Covered Recipient Physician                    NaN
#
#    teaching_hospital_id teaching_hospital_name  covered_recipient_profile_id  \
# 0                   NaN                    NaN                       92058.0
# ...
